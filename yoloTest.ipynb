# %%
test = """Epoch 0 using lr = 1e-05 TrainingMSE: 0.24650328377118477, ValidMSE: 0.19375486175219217, trainR2 = -7.625267733626556, evalR2= -12.356705763269654
Epoch 1 using lr = 1e-05 TrainingMSE: 0.18768594356683585, ValidMSE: 0.22018982470035553, trainR2 = -12.214109572149878, evalR2= -8.384807029140058
Epoch 2 using lr = 1e-05 TrainingMSE: 0.1760681735781523, ValidMSE: 0.17714243630568186, trainR2 = -16.73048399197644, evalR2= -20.757941338389095
Epoch 3 using lr = 1e-05 TrainingMSE: 0.16484679396335894, ValidMSE: 0.16567627092202505, trainR2 = -22.1752094720062, evalR2= -45.04963277928502
Epoch 4 using lr = 1e-05 TrainingMSE: 0.1575962551511251, ValidMSE: 0.16889413197835287, trainR2 = -32.81867493022851, evalR2= -27.80360850972889
Epoch 5 using lr = 1e-05 TrainingMSE: 0.15647497200048888, ValidMSE: 0.16427722573280334, trainR2 = -35.09076421157616, evalR2= -35.641196329953694
Epoch 6 using lr = 1e-05 TrainingMSE: 0.15564923790784982, ValidMSE: 0.16318556666374207, trainR2 = -35.96132734104747, evalR2= -39.145821150269136
Epoch 7 using lr = 1e-05 TrainingMSE: 0.1537240118934558, ValidMSE: 0.16099330286184946, trainR2 = -42.269807393690584, evalR2= -47.73509331838227
Epoch 8 using lr = 1e-05 TrainingMSE: 0.15184346873026627, ValidMSE: 0.16702192525068918, trainR2 = -45.19708969757432, evalR2= -33.47447206920615
Epoch 9 using lr = 1e-05 TrainingMSE: 0.1529601623232548, ValidMSE: 0.1609935313463211, trainR2 = -49.078086689815564, evalR2= -55.8409053744091
Epoch 11 using lr = 1e-05 TrainingMSE: 0.15181895574698082, ValidMSE: 0.1595749408006668, trainR2 = -49.72943311658242, evalR2= -64.03805876632208
Epoch 12 using lr = 1e-05 TrainingMSE: 0.15166527663285917, ValidMSE: 0.1594913750886917, trainR2 = -67.7119690115551, evalR2= -55.474116812966635
Epoch 13 using lr = 1e-05 TrainingMSE: 0.15293799913846529, ValidMSE: 0.1594665745894114, trainR2 = -56.15792784313115, evalR2= -55.58497980355838
Epoch 14 using lr = 1e-05 TrainingMSE: 0.15033111090843493, ValidMSE: 0.1610065996646881, trainR2 = -56.71758709772686, evalR2= -53.218392007138895
Epoch 15 using lr = 1e-05 TrainingMSE: 0.149626782307258, ValidMSE: 0.1597311000029246, trainR2 = -60.92608237818389, evalR2= -41.714277238061605
Epoch 16 using lr = 1e-05 TrainingMSE: 0.14969483189857924, ValidMSE: 0.16075542569160461, trainR2 = -59.08405926474505, evalR2= -50.44897151484258
Epoch 17 using lr = 1e-05 TrainingMSE: 0.14929455490066454, ValidMSE: 0.15939724445343018, trainR2 = -57.58491004859822, evalR2= -57.94167399290697"""

# %%
trainMSE = [float(line.split("TrainingMSE: ")[1].split(",")[0]) for line in test.splitlines()]
validMSE = [float(line.split("ValidMSE: ")[1].split(",")[0]) for line in test.splitlines()]
trainR2 = [float(line.split("trainR2 = ")[1].split(",")[0]) for line in test.splitlines()]
validR2 = [float(line.split("evalR2= ")[1].split(",")[0]) for line in test.splitlines()]

# %%
for thing in trainMSE:
    print(f"{thing},", end="")

# %%
for thing in validMSE:
    print(f"{thing},", end="")

# %%
for thing in trainR2:
    print(f"{thing},", end="")

# %%
for thing in validR2:
    print(f"{thing},", end="")
# Out:
# -12.356705763269654,-8.384807029140058,-20.757941338389095,-45.04963277928502,-27.80360850972889,-35.641196329953694,-39.145821150269136,-47.73509331838227,-33.47447206920615,-55.8409053744091,-64.03805876632208,-55.474116812966635,-55.58497980355838,-53.218392007138895,-41.714277238061605,-50.44897151484258,-57.94167399290697,

# %%
from ultralytics import YOLO
from PIL import Image
import torch
from torchvision.models import vgg19
from torchvision import ops
from torchvision import transforms
import numpy as np

# %%
yoloModel = YOLO('yolov8n.pt')

# %%
testImage = Image.open("C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader/algonauts_2023_challenge_data/subj01/training_split/training_images/train-0001_nsd-00013.png")
testImage2 = Image.open("C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader/algonauts_2023_challenge_data/subj01/training_split/training_images/train-0105_nsd-00868.png")

# %%
testImage = Image.open("C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader/algonauts_2023_challenge_data/subj01/training_split/training_images/train-0001_nsd-00013.png")
testImage2 = Image.open("C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader/algonauts_2023_challenge_data/subj01/training_split/training_images/train-0105_nsd-00868.png")

# %%
tsfms = transforms.Compose([
    transforms.Resize((640, 640)),
    transforms.ToTensor()
])

# %%
images = [tsfms(Image.open(f"C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader{image}")) for image in images]

# %%
torch.stack(images).shape
# Out:
# torch.Size([64, 3, 425, 425])

# %%
res = yoloModel.predict(input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 res = yoloModel.predict(torch.stack(images))
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:248, in Model.predict(self, source, stream, predictor, **kwargs)
#     246 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     247     self.predictor.set_prompts(prompts)
# --> 248 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:194, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     192     return self.stream_inference(source, model, *args, **kwargs)
#     193 else:
# --> 194     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:229, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     226     self.setup_model(model)
#     228 # Setup source every time predict is called
# --> 229 self.setup_source(source if source is not None else self.args.source)
#     231 # Check if save_dir/ label file exists
#     232 if self.args.save or self.args.save_txt:
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:207, in BasePredictor.setup_source(self, source)
#     204 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     205 self.transforms = getattr(self.model.model, 'transforms', classify_transforms(
#     206     self.imgsz[0])) if self.args.task == 'classify' else None
# --> 207 self.dataset = load_inference_source(source=source,
#     208                                      imgsz=self.imgsz,
#     209                                      vid_stride=self.args.vid_stride,
#     210                                      buffer=self.args.stream_buffer)
#     211 self.source_type = self.dataset.source_type
#     212 if not getattr(self, 'stream', True) and (self.dataset.mode == 'stream' or  # streams
#     213                                           len(self.dataset) > 1000 or  # images
#     214                                           any(getattr(self.dataset, 'video_flag', [False]))):  # videos
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\data\build.py:156, in load_inference_source(source, imgsz, vid_stride, buffer)
#     154 # Dataloader
#     155 if tensor:
# --> 156     dataset = LoadTensor(source)
#     157 elif in_memory:
#     158     dataset = source
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\data\loaders.py:331, in LoadTensor.__init__(self, im0)
#     330 def __init__(self, im0) -> None:
# --> 331     self.im0 = self._single_check(im0)
#     332     self.bs = self.im0.shape[0]
#     333     self.mode = 'image'
#
# File c:\Users\josem\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\data\loaders.py:347, in LoadTensor._single_check(im, stride)
#     345     im = im.unsqueeze(0)
#     346 if im.shape[2] % stride or im.shape[3] % stride:
# --> 347     raise ValueError(s)
#     348 if im.max() > 1.0:
#     349     LOGGER.warning(f'WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is {im.max()}. '
#     350                    f'Dividing input by 255.')
#
# ValueError: WARNING ⚠️ torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(64, 3, 425, 425) is incompatible.

# %%
for i in range(len(images)):
    res = yoloModel.predict(images[i])[0].boxes.cls
    num = len(res)
    if num == 0:
        print(f"here bitch {i}")
    print(len(res))
# Out:
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 7 persons, 6 bananas, 232.2ms
# Speed: 7.0ms preprocess, 232.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 2 surfboards, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 dog, 1 frisbee, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 skis, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 kite, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 pizza, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 skis, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 bowl, 13 donuts, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 skateboard, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 sandwich, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 kite, 7.0ms
# 13
# 3
# 1
# 3
# 3
# 3
# 4
# 2
# 15
# 2
# 2
# Speed: 1.0ms preprocess, 7.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 couch, 6 remotes, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 sports ball, 10 kites, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 sink, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 10 persons, 1 skateboard, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 2 skateboards, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 frisbee, 1 bottle, 1 cake, 1 chair, 1 couch, 1 potted plant, 1 dining table, 3 tvs, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 bench, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 remote, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 4 persons, 1 kite, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 7.0ms
# 2
# 10
# 14
# 3
# 11
# 3
# 11
# 4
# 4
# 5
# 2
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 car, 1 tennis racket, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 backpack, 1 skis, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 5 persons, 2 skiss, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 chair, 3 remotes, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 5 persons, 2 baseball bats, 2 baseball gloves, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 9 persons, 3 skateboards, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 6 persons, 1 suitcase, 1 skis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 7.7ms
# Speed: 1.5ms preprocess, 7.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 skis, 8.0ms
# 2
# 3
# 3
# 7
# 6
# 9
# 12
# here bitch 29
# 0
# 8
# 1
# 2
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 4 persons, 1 umbrella, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 snowboard, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 car, 1 cup, 3 bowls, 1 broccoli, 1 chair, 2 dining tables, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 11 persons, 1 cow, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 2 baseball bats, 1 baseball glove, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 surfboard, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 2 surfboards, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 2 sports balls, 1 baseball bat, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 2 surfboards, 8.0ms
# 2
# 5
# 2
# 2
# 11
# 12
# 6
# 2
# 2
# 2
# 4
# 6
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 3 bowls, 1 orange, 1 carrot, 1 sink, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 4 persons, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 cup, 3 bowls, 1 oven, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 7 persons, 2 surfboards, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 3 snowboards, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 4 persons, 2 pizzas, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 1 giraffe, 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 6 persons, 2 birds, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 7.0ms
# 3
# 7
# 4
# 6
# 9
# 6
# 1
# here bitch 52
# 0
# 6
# 3
# 8
# Speed: 2.0ms preprocess, 7.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 giraffe, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 3 persons, 5 kites, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 motorcycle, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 12 persons, 11 suitcases, 1 chair, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 2 persons, 2 baseball bats, 1 baseball glove, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 640, 640) is incompatible.
# 0: 640x640 1 person, 1 skis, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# 1
# 8
# 1
# 8
# 2
# 24
# 5
# 2

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(images[52].permute(1,2,0))

# %%
res = yoloModel.predict(Image.open(f"C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader{images[7]}"))
# Out:
# 0: 640x640 5 persons, 4 kites, 135.6ms
# Speed: 7.0ms preprocess, 135.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
dummyData = torch.vstack((tsfms(testImage)[None, :, :, :], tsfms(testImage2)[None, :, :, :]))

# %%
results = yoloModel.predict(dummyData)
# Out:
# 0: 224x224 1 chair, 1: 224x224 2 persons, 3 elephants, 47.7ms
# Speed: 0.5ms preprocess, 23.9ms inference, 1.9ms postprocess per image at shape (1, 3, 224, 224)

# %%
test = [result.boxes for result in results]
mappedBoxes = []
for result in test:
    print(result)
    boundingBoxData = result.xyxyn
    boundingBoxStartX, boundingBoxStartY, boundingBoxEndX, boundingBoxEndY = boundingBoxData[:, 0], boundingBoxData[:, 1], boundingBoxData[:, 2], boundingBoxData[:, 3]
    transformedBoundingBoxStartX, transformedBoundingBoxStartY, transformedBoundingBoxEndX, transformedBoundingBoxEndY = boundingBoxStartX * 7, boundingBoxStartY * 7, boundingBoxEndX * 7, boundingBoxEndY * 7
    startCellX = torch.floor(transformedBoundingBoxStartX)
    startCellY = torch.floor(transformedBoundingBoxStartY)
    endCellX = torch.ceil(transformedBoundingBoxEndX)
    endCellY = torch.ceil(transformedBoundingBoxEndY)
    mappedBoxes.append(torch.hstack(startCellX.reshape(-1,1), startCellY.reshape(-1,1), endCellX.reshape(-1,1), torch.tensor(endCellY).reshape(-1,1)))

torch.tensor(mappedBoxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([56.], device='cuda:0')
# conf: tensor([0.8569], device='cuda:0')
# data: tensor([[1.1782e-01, 1.3346e+02, 6.4672e+01, 2.2363e+02, 8.5695e-01, 5.6000e+01]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (224, 224)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 32.3947, 178.5463,  64.5537,  90.1748]], device='cuda:0')
# xywhn: tensor([[0.1446, 0.7971, 0.2882, 0.4026]], device='cuda:0')
# xyxy: tensor([[1.1782e-01, 1.3346e+02, 6.4672e+01, 2.2363e+02]], device='cuda:0')
# xyxyn: tensor([[5.2599e-04, 5.9580e-01, 2.8871e-01, 9.9836e-01]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([ 0.,  0., 20., 20., 20.], device='cuda:0')
# conf: tensor([0.7484, 0.6573, 0.4192, 0.3392, 0.2685], device='cuda:0')
# data: tensor([[4.8065e-04, 7.3214e+01, 4.2213e+01, 2.1964e+02, 7.4843e-01, 0.0000e+00],
#         [4.0169e+01, 9.1660e+01, 8.0540e+01, 2.0817e+02, 6.5734e-01, 0.0000e+00],
#         [8.6638e+01, 1.1993e+02, 1.4498e+02, 1.7621e+02, 4.1921e-01, 2.0000e+01],
#         [9.4496e+01, 7.5236e+01, 1.3859e+02, 1.0771e+02, 3.3922e-01, 2.0000e+01],
#         [8.0631e+01, 1.1377e+02, 1.7245e+02, 1.7408e+02, 2.6850e-01, 2.0000e+01]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (224, 224)
# shape: torch.Size([5, 6])
# xywh: tensor([[ 21.1068, 146.4292,  42.2126, 146.4305],
#         [ 60.3546, 149.9126,  40.3704, 116.5062],
#         [115.8092, 148.0724,  58.3429,  56.2826],
#         [116.5426,  91.4713,  44.0941,  32.4704],
#         [126.5422, 143.9232,  91.8232,  60.3157]], device='cuda:0')
# xywhn: tensor([[0.0942, 0.6537, 0.1884, 0.6537],
#         [0.2694, 0.6693, 0.1802, 0.5201],
#         [0.5170, 0.6610, 0.2605, 0.2513],
#         [0.5203, 0.4084, 0.1968, 0.1450],
#         [0.5649, 0.6425, 0.4099, 0.2693]], device='cuda:0')
# xyxy: tensor([[4.8065e-04, 7.3214e+01, 4.2213e+01, 2.1964e+02],
#         [4.0169e+01, 9.1660e+01, 8.0540e+01, 2.0817e+02],
#         [8.6638e+01, 1.1993e+02, 1.4498e+02, 1.7621e+02],
#         [9.4496e+01, 7.5236e+01, 1.3859e+02, 1.0771e+02],
#         [8.0631e+01, 1.1377e+02, 1.7245e+02, 1.7408e+02]], device='cuda:0')
# xyxyn: tensor([[2.1458e-06, 3.2685e-01, 1.8845e-01, 9.8056e-01],
#         [1.7933e-01, 4.0919e-01, 3.5955e-01, 9.2931e-01],
#         [3.8678e-01, 5.3541e-01, 6.4724e-01, 7.8667e-01],
#         [4.2186e-01, 3.3588e-01, 6.1870e-01, 4.8083e-01],
#         [3.5996e-01, 5.0788e-01, 7.6988e-01, 7.7715e-01]], device='cuda:0')
# tensor([])

# %%
boundingBoxData = results[0].boxes.xywh

# %%
boundingBoxData[0].reshape(-1, 1)
# Out:
# tensor([[0.],
#         [2.],
#         [2.],
#         [7.]])

# %%
boundingBoxStartX, boundingBoxStartY, boundingBoxEndX, boundingBoxEndY = boundingBoxData[:, 0], boundingBoxData[:, 1], boundingBoxData[:, 2], boundingBoxData[:, 3]

# %%
boundingBoxStartX * .97
# Out:
# tensor([0.0000, 0.9700, 1.9400, 1.9400, 1.9400])

# %%
torch.ceil(boundingBoxStartX * .97)
# Out:
# tensor([0., 1., 2., 2., 2.])

# %%
test = torch.rand(1, 512, 7, 7)

# %%
torch.flatten(test).shape
# Out:
# torch.Size([25088])

# %%
for i in results:
    data = i.boxes
    # print(data.xywh.cpu().numpy())
    boundingBoxData = data.xyxyn
    boundingBoxStartX, boundingBoxStartY, boundingBoxEndX, boundingBoxEndY = boundingBoxData[:, 0], boundingBoxData[:, 1], boundingBoxData[:, 2], boundingBoxData[:, 3]

    transformedBoundingBoxStartX, transformedBoundingBoxStartY, transformedBoundingBoxEndX, transformedBoundingBoxEndY = boundingBoxStartX * 7, boundingBoxStartY * 7, boundingBoxEndX * 7, boundingBoxEndY * 7
    startCellX = torch.floor(transformedBoundingBoxStartX)
    startCellY = torch.floor(transformedBoundingBoxStartY)

    endCellX = torch.ceil(transformedBoundingBoxEndX)
    endCellY = torch.ceil(transformedBoundingBoxEndY)

    print(boundingBoxStartX[0], boundingBoxStartY[0], boundingBoxEndX[0], boundingBoxEndY[0])
    print(transformedBoundingBoxStartX[0], transformedBoundingBoxStartY[0], transformedBoundingBoxEndX[0], transformedBoundingBoxEndY[0])
    print(startCellX, startCellY, endCellX, endCellY)
    
    boundingBoxData = torch.hstack((torch.reshape(torch.tensor(startCellX), (-1,1)), torch.reshape(torch.tensor(startCellY), (-1,1)), torch.reshape(torch.tensor(endCellX), (-1,1)), torch.reshape(torch.tensor(endCellY), (-1,1))))
    # print(ops.roi_pool())

    # torch.cat((torch.reshape(torch.tensor(startCellX), (-1,1)), torch.reshape(torch.tensor(startCellY), (-1,1)), torch.reshape(torch.tensor(endCellX), (-1,1)), torch.reshape(torch.tensor(endCellY), (-1,1))),1)
    roiPooled = ops.roi_pool(testAvgPool.to("cuda:0"), [newBBData.to("cuda:0")], output_size = (7,7))
    # newBBData = torch.cat((torch.reshape(torch.tensor(startCellX), (-1,1)), torch.reshape(torch.tensor(startCellY), (-1,1)), torch.reshape(torch.tensor(endCellX), (-1,1)), torch.reshape(torch.tensor(endCellY), (-1,1))),1)
    torch.hstack((torch.reshape(torch.tensor(startCellX), (-1,1)), torch.reshape(torch.tensor(startCellY), (-1,1)), torch.reshape(torch.tensor(endCellX), (-1,1)), torch.reshape(torch.tensor(endCellY), (-1,1))))
    # boundingBoxData = data.xyxyn.cpu().numpy()
    # boundingBoxStartX, boundingBoxStartY, boundingBoxWidth, boundingBoxHeight = boundingBoxData[:, 0], boundingBoxData[:, 1], boundingBoxData[:, 2], boundingBoxData[:, 3]

    # transformedBoundingBoxStartX, transformedBoundingBoxStartY, transformedBoundingBoxWidth, transformedBoundingBoxHeight = boundingBoxStartX * 7, boundingBoxStartY * 7, boundingBoxWidth * 7, boundingBoxHeight * 7
    # startCellX = np.floor(transformedBoundingBoxStartX)
    # startCellY = np.floor(transformedBoundingBoxStartY)

    # endCellX = np.ceil(transformedBoundingBoxStartX + transformedBoundingBoxWidth)
    # endCellY = np.ceil(transformedBoundingBoxStartY + transformedBoundingBoxHeight)

    # print(boundingBoxStartX[0], boundingBoxStartY[0], boundingBoxWidth[0], boundingBoxHeight[0])
    # print(transformedBoundingBoxStartX[0], transformedBoundingBoxStartY[0], transformedBoundingBoxWidth[0], transformedBoundingBoxHeight[0])
    # print(startCellX[0], startCellY[0], endCellX[0], endCellY[0])


    # classPred = data.cls
    # confidence = data.conf
    # boundingBoxPos = data.xywh

    # print(classPred)
    # print(confidence)
    # print(boundingBoxPos)
# Out:
# tensor(2.1458e-06, device='cuda:0') tensor(0.3268, device='cuda:0') tensor(0.1885, device='cuda:0') tensor(0.9806, device='cuda:0')
# tensor(1.5020e-05, device='cuda:0') tensor(2.2879, device='cuda:0') tensor(1.3192, device='cuda:0') tensor(6.8639, device='cuda:0')
# tensor([0., 1., 2., 2., 2.], device='cuda:0') tensor([2., 2., 3., 2., 3.], device='cuda:0') tensor([2., 3., 5., 5., 6.], device='cuda:0') tensor([7., 7., 6., 4., 6.], device='cuda:0')

# %%
import cv2
import numpy as np

def draw_boxes(image, boxes, class_names, confidence_threshold=0.5):
    # Iterate through the detected boxes
    for box in boxes:
        x, y, width, height = box

        # Filter boxes based on confidence threshold
        # if confidence >= confidence_threshold:
        # Convert relative coordinates to absolute coordinates
        h, w, _ = image.shape
        x = int(x * w)
        y = int(y * h)
        width = int(width * w)
        height = int(height * h)

        # Calculate box coordinates
        x_min, y_min = x - width // 2, y - height // 2
        x_max, y_max = x_min + width, y_min + height

        # Draw bounding box on the image
        color = (0, 255, 0)  # Green color
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color, 2)

        # # Display class label and confidence
        # label = f"{class_names[class_index]}: {confidence:.2f}"
        # cv2.putText(image, label, (x_min, y_min - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    return image

# Example bounding box data
# Each box is represented as (class_index, confidence, x, y, width, height)
bounding_boxes = [
    [     21.107,      146.43,      42.213,      146.43],
    [     60.355,      149.91,       40.37,      116.51],
    [     115.81,      148.07,      58.343,      56.283],
    [     116.54,      91.471,      44.094,       32.47],
    [     126.54,      143.92,      91.823,      60.316]
]

# Example class names
class_names = ["Class A", "Class B"]

# Example image
image_path = "C:/Users/josem/Documents/schoolWork/MQP/algonauts2023_transformers#2Leader/algonauts_2023_challenge_data/subj01/training_split/training_images/train-0105_nsd-00868.png"
original_image = cv2.imread(image_path)
original_image = cv2.resize(original_image, (224, 224))

# Draw bounding boxes on the original image
image_with_boxes = draw_boxes(original_image.copy(), bounding_boxes, class_names)

# Display the original and annotated images
cv2.imshow("Original Image", original_image)
cv2.imshow("Image with Bounding Boxes", image_with_boxes)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
class ROIVGG(torch.nn.Module):
    def __init__(self, numClasses: int, numROIs: int, cocoVGGWeights:str = None, device: str = "cuda"):
        super(ROIVGG, self).__init__()
        self.cocoVgg19 = CocoVGG(numClasses)
        if cocoVGGWeights is not None:
            self.cocoVgg19.load_state_dict(torch.load(cocoVGGWeights, map_location=device))
            
        self.convFeatures = self.cocoVgg19.features[:36]
        self.maxPool = torch.nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 0, dilation = 1, ceil_mode = False)
        self.adaptiveAvgPool = torch.nn.AdaptiveAvgPool2d(output_size = (7, 7))
        self.cocoClassifier = self.cocoVgg19.classifier
        self.roiClassifier = torch.nn.Sequential(
            torch.nn.Linear(in_features = 25088, out_features = 4096),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(in_features = 4096, out_features = 1024),#1024
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(in_features = 1024, out_features = numROIs)
        )
        self.gradients = None
    def activations_hook(self, grad):
        self.gradients = grad
    def forward(self, img):
        extractedFeatures = self.convFeatures(img)
        # hook = extractedFeatures.register_hook(self.activations_hook)
        intermediateOutput = self.maxPool(extractedFeatures)
        intermediateOutput = self.adaptiveAvgPool(intermediateOutput)
        intermediateOutput = torch.flatten(intermediateOutput, 1)
        return self.cocoClassifier(intermediateOutput), self.roiClassifier(intermediateOutput)
    def get_activation_gradient(self):
        return self.gradients
    def get_activations(self, img):
        return self.convFeatures(img)
    def __str__(self):
        return ""
    def __repr__(self):
        return ""

# %%
class roiVGGYolo(torch.nn.Module):
    def __init__(self, numROIs: int):
        super(roiVGGYolo, self).__init__()
        self.vgg = vgg19(weights = "DEFAULT")
        for params in self.vgg.parameters():
            params.requires_grad = False
        self.yolo = YOLO("yolov8n.pt")
        for params in self.yolo.parameters():
            params.requires_grad = False
        self.MLP = torch.nn.Sequential(
            torch.nn.Linear(25088, 4096),
            torch.nn.ReLU(),
            torch.nn.Linear(4096, 1024),
            torch.nn.ReLU(),
            torch.nn.Linear(1024, numROIs),
        )
    def forward(self, img):
        pooling = self.vgg.features(img)
        pooling = self.vgg.avgpool(pooling)
        yoloResults = [results.boxes for results in self.yolo.predict(img)]
        boundingBoxDataAllImages = self.getMappedBoundingBox(yoloResults)
        finalFMRIs = []
        for boundingBoxData in boundingBoxDataAllImages:
            objectROIPools = ops.roi_pool(pooling, [boundingBoxData], output_size = (7,7))
            fmriPieces = []
            for objectROIPool in objectROIPools:
                input = torch.flatten(objectROIPool)
                fmriPieces.append(self.MLP(input))
            totalFMRI = torch.sum(torch.stack(fmriPieces), dim=0)
            finalFMRIs.append(totalFMRI)
        return torch.stack(finalFMRIs)   
    def getMappedBoundingBox(self, yoloResults):
        mappedBoxes = []
        for result in yoloResults:
            boundingBoxData = result.xyxyn
            boundingBoxStartX, boundingBoxStartY, boundingBoxEndX, boundingBoxEndY = boundingBoxData[:, 0], boundingBoxData[:, 1], boundingBoxData[:, 2], boundingBoxData[:, 3]
            transformedBoundingBoxStartX, transformedBoundingBoxStartY, transformedBoundingBoxEndX, transformedBoundingBoxEndY = boundingBoxStartX * 7, boundingBoxStartY * 7, boundingBoxEndX * 7, boundingBoxEndY * 7
            startCellX = torch.floor(transformedBoundingBoxStartX)
            startCellY = torch.floor(transformedBoundingBoxStartY)
            endCellX = torch.ceil(transformedBoundingBoxEndX)
            endCellY = torch.ceil(transformedBoundingBoxEndY)
            mappedBoxes.append(torch.hstack((startCellX.reshape(-1,1), startCellY.reshape(-1,1), endCellX.reshape(-1,1), endCellY.reshape(-1,1))))
        return mappedBoxes
# Out:
#   Cell In[17], line 7
#     self.yolo = YOLO("yolov8n.pt")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 5
